# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data1 = np.linspace(0,10,20)

# %%
data1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
data2 = data1 ** 2

# %%
plt.subplots()
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
my_fig, my_axes  = plt.subplots()

# %%
type(my_fig)
# Out:
# matplotlib.figure.Figure

# %%
type(my_axes)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
my_fig, my_axes  = plt.subplots()
my_axes.plot(data1, data2, color="#1E0703", alpha=0.5)
my_axes.plot(data2, data1, color="#555703")
plt.show()

# %%
(new_fig, new_axes) = plt.subplots()

new_axes.plot(data1, data1 + 2, color="blue", linewidth=1.0)
new_axes.plot(data1, data1 + 3, color="yellow", linewidth=4.0)

new_axes.plot(data1, data1 + 4, color="#c85d09", linestyle = "-.")
new_axes.plot(data1, data1 + 5, color="#c85d09", linestyle = ":")
new_axes.plot(data1, data1 + 6, color="#c85d09", linestyle = "--")

new_axes.plot(data1, data1 + 7, color="#000000", linestyle = "--", marker="o", markersize=8, markerfacecolor="red")
new_axes.plot(data1, data1 + 8, color="#000000", linestyle = "--", marker="+", markersize=4)

plt.show()

# %%
# scatter

# %%
plt.scatter(data1, data2, color="black")
plt.show()

# %%
#histogram

# %%
new_arr = np.random.randint(0,100,50)

# %%
new_arr
# Out:
# array([52,  6, 13, 74, 15, 56,  1, 47, 40, 41, 90, 93, 73, 61, 38, 21, 28,
#        61, 34, 10, 40, 61, 43, 56, 23, 23, 59, 88, 92, 57, 57, 36, 95, 70,
#        76, 14, 18, 30, 71, 20, 89, 92, 34, 25, 58, 97, 96, 34,  6, 49])

# %%
plt.hist(new_arr)
plt.show()

# %%
#box_plot

# %%
plt.boxplot(new_arr)
plt.show()
